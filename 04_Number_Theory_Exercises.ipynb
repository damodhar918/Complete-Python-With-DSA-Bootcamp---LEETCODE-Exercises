# %% [markdown]
# ## Coding Exercise 36: Sum of N Even Natural Numbers
#
# Write a function to calculate the sum of first N even natural numbers.
#
# **Formula:** Sum = 2 + 4 + 6 + ... + 2N = N(N+1)
#
# **Example:**
# - Input: 5, Output: 30 (2+4+6+8+10)
# - Input: 3, Output: 12 (2+4+6)
# - Input: 1, Output: 2

# %%
# Exercise 36: Sum of N Even Natural Numbers
def sum_n_even_numbers(n):
    """
    Calculate the sum of first N even natural numbers
    
    Args:
        n (int): N value
    
    Returns:
        int: Sum of first N even natural numbers
    """
    return n * (n + 1)

# Test
test_cases = [5, 3, 1, 10]
for n in test_cases:
    result = sum_n_even_numbers(n)
    print(f"Input: {n}, Output: {result}")
# Out:
# Input: 5, Output: 30
# Input: 3, Output: 12
# Input: 1, Output: 2
# Input: 10, Output: 110

# %% [markdown]
# ## Coding Exercise 37: Check for Even Number
#
# Write a function to check if a number is even.
#
# **Logic:** A number is even if it is divisible by 2 (number % 2 == 0)
#
# **Example:**
# - Input: 4, Output: True
# - Input: 7, Output: False
# - Input: 0, Output: True

# %%
# Exercise 37: Check for Even Number
def is_even(num):
    """
    Check if a number is even
    
    Args:
        num (int): Number to check
    
    Returns:
        bool: True if even, False otherwise
    """
    return num % 2 == 0

# Test
test_cases = [4, 7, 0, 15, 100]
for num in test_cases:
    result = is_even(num)
    print(f"Input: {num}, Output: {result}")
# Out:
# Input: 4, Output: True
# Input: 7, Output: False
# Input: 0, Output: True
# Input: 15, Output: False
# Input: 100, Output: True

# %% [markdown]
# ## Coding Exercise 38: Check for Prime Number
#
# Write a function to check if a number is prime.
#
# **Logic:** A prime number is divisible only by 1 and itself. Numbers less than 2 are not prime.
#
# **Example:**
# - Input: 7, Output: True
# - Input: 10, Output: False
# - Input: 2, Output: True
# - Input: 1, Output: False

# %%
# Exercise 38: Check for Prime Number
def is_prime(num):
    """
    Check if a number is prime
    
    Args:
        num (int): Number to check
    
    Returns:
        bool: True if prime, False otherwise
    """
    if num < 2:
        return False
    if num == 2:
        return True
    if num % 2 == 0:
        return False
    for i in range(3, int(num**0.5) + 1, 2):
        if num % i == 0:
            return False
    return True

# Test
test_cases = [7, 10, 2, 1, 17, 20]
for num in test_cases:
    result = is_prime(num)
    print(f"Input: {num}, Output: {result}")
# Out:
# Input: 7, Output: True
# Input: 10, Output: False
# Input: 2, Output: True
# Input: 1, Output: False
# Input: 17, Output: True
# Input: 20, Output: False

# %%
def check_prime(n):
    """
    Check if a number is prime
    
    Args:
        n (int): Number to check
    
    Returns:
        bool: True if prime, False otherwise
    """
    if n <= 1:
        return False
    if n == 2:  # 2 is a prime number
        return True
    if n % 2 == 0:  # Any even number greater than 2 is not prime
        return False

    # Check divisibility for odd numbers from 3 up to sqrt(n)
    i = 3
    while i * i <= n:
        if n % i == 0:
            return False
        i += 2  # Skip even numbers

    return True

# Test
test_cases = [77, 2, 7, 10, 1, 17, 20]
for num in test_cases:
    result = check_prime(num)
    print(f"Input: {num}, Output: {result}")
# Out:
# Input: 77, Output: False
# Input: 2, Output: True
# Input: 7, Output: True
# Input: 10, Output: False
# Input: 1, Output: False
# Input: 17, Output: True
# Input: 20, Output: False

# %% [markdown]
# ## Coding Exercise 39: Valid Perfect Square
#
# Write a function to check if a number is a perfect square.
#
# **Logic:** A perfect square is a number that can be expressed as the square of an integer.
#
# **Example:**
# - Input: 16, Output: True (4²)
# - Input: 15, Output: False
# - Input: 25, Output: True (5²)
# - Input: 1, Output: True (1²)

# %%
# Exercise 39: Valid Perfect Square
import math

def is_perfect_square(num):
    """
    Check if a number is a perfect square
    
    Args:
        num (int): Number to check
    
    Returns:
        bool: True if perfect square, False otherwise
    """
    if num < 0:
        return False
    sqrt = int(math.sqrt(num))
    return sqrt * sqrt == num

# Test
test_cases = [16, 15, 25, 1, 100, 50]
for num in test_cases:
    result = is_perfect_square(num)
    print(f"Input: {num}, Output: {result}")
# Out:
# Input: 16, Output: True
# Input: 15, Output: False
# Input: 25, Output: True
# Input: 1, Output: True
# Input: 100, Output: True
# Input: 50, Output: False

# %% [markdown]
# ## Coding Exercise 40: Decimal to Binary
#
# Write a function to convert a decimal number to binary.
#
# **Example:**
# - Input: 10, Output: '1010'
# - Input: 5, Output: '101'
# - Input: 8, Output: '1000'
# - Input: 0, Output: '0'

# %%
# Exercise 40: Decimal to Binary
def decimal_to_binary(num):
    """
    Convert decimal number to binary without using built-in functions
    
    Args:
        num (int): Decimal number
    
    Returns:
        str: Binary representation
    """
    if num == 0:
        return '0'
    
    is_negative = num < 0
    num = abs(num)
    
    binary = ''
    while num > 0:
        binary = str(num % 2) + binary
        num //= 2
    
    return '-' + binary if is_negative else binary

# Test
test_cases = [10, 5, 8, 0, 15, 255, -5, -10]
for num in test_cases:
    result = decimal_to_binary(num)
    print(f"Input: {num}, Output: '{result}'")
# Out:
# Input: 10, Output: '1010'
# Input: 5, Output: '101'
# Input: 8, Output: '1000'
# Input: 0, Output: '0'
# Input: 15, Output: '1111'
# Input: 255, Output: '11111111'
# Input: -5, Output: '-101'
# Input: -10, Output: '-1010'

# %%
n = -10092
if n<0:
    ne= '-'
else:
    ne =''

ne + bin(abs(n))[2:]
# Out:
# '-10011101101100'

# %% [markdown]
# ## Coding Exercise 41: Binary to Decimal
#
# Write a function to convert a binary number to decimal.
#
# **Example:**
# - Input: '1010', Output: 10
# - Input: '101', Output: 5
# - Input: '1000', Output: 8
# - Input: '0', Output: 0

# %%
# Exercise 41: Binary to Decimal
def binary_to_decimal(binary_str):
    """
    Convert binary number to decimal
    
    Args:
        binary_str (str): Binary number as string
    
    Returns:
        int: Decimal representation
    """
    return int(binary_str, 2)

# Test
test_cases = ['1010', '101', '1000', '0', '1111', '11111111']
for binary_str in test_cases:
    result = binary_to_decimal(binary_str)
    print(f"Input: '{binary_str}', Output: {result}")
# Out:
# Input: '1010', Output: 10
# Input: '101', Output: 5
# Input: '1000', Output: 8
# Input: '0', Output: 0
# Input: '1111', Output: 15
# Input: '11111111', Output: 255

# %% [markdown]
# ## Coding Exercise 42: GCD of Two Numbers
#
# Write a function to find the Greatest Common Divisor (GCD) of two numbers.
#
# **Logic:** GCD is the largest positive integer that divides both numbers without remainder.
#
# **Example:**
# - Input: 12, 8, Output: 4
# - Input: 15, 25, Output: 5
# - Input: 7, 13, Output: 1
# - Input: 100, 50, Output: 50

# %%
# Exercise 42: GCD of Two Numbers
import math

def gcd_of_two(a, b):
    """
    Find the GCD of two numbers
    
    Args:
        a (int): First number
        b (int): Second number
    
    Returns:
        int: GCD of a and b
    """
    return math.gcd(a, b)

# Test
test_cases = [(12, 8), (15, 25), (7, 13), (100, 50), (48, 18)]
for a, b in test_cases:
    result = gcd_of_two(a, b)
    print(f"Input: {a}, {b}, Output: {result}")
# Out:
# Input: 12, 8, Output: 4
# Input: 15, 25, Output: 5
# Input: 7, 13, Output: 1
# Input: 100, 50, Output: 50
# Input: 48, 18, Output: 6
